# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sweetviz as sv

# %%
import csv
def load_csv(filename):
    """Helper to load the tournament data from csv."""
    rows = []
    with open(filename) as f:
        reader = csv.DictReader(f)
        rows.extend(iter(reader))
    return rows

# %%
fp_one = '/Users/christopherfiore/Documents/GitHub/cwl-data/data/data-2017-08-13-champs.csv'
fp_two = '/Users/christopherfiore/Documents/GitHub/cwl-data/data/data-2018-08-19-champs.csv'
champs_2017 = pd.DataFrame(load_csv(fp_one))
champs_2018 = pd.DataFrame(load_csv(fp_two))

# %%
champs_2017.head()
# Out:
#                                match id        series id  \
# 0  3A6D1AC2-1118-11D3-A6EB-0CFE456F15BE  champs-pool-A-3
# 1  3A6D1AC2-1118-11D3-A6EB-0CFE456F15BE  champs-pool-A-3
# 2  3A6D1AC2-1118-11D3-A6EB-0CFE456F15BE  champs-pool-A-3
# 3  3A6D1AC2-1118-11D3-A6EB-0CFE456F15BE  champs-pool-A-3
# 4  3A6D1AC2-1118-11D3-A6EB-0CFE456F15BE  champs-pool-A-3
#
#                   end time duration (s)       mode          map      team  \
# 0  2017-08-09 14:11:50 UTC        480.0  Hardpoint  Retaliation  Echo Fox
# 1  2017-08-09 14:11:50 UTC        480.0  Hardpoint  Retaliation  Echo Fox
# 2  2017-08-09 14:11:50 UTC        480.0  Hardpoint  Retaliation  Echo Fox
# 3  2017-08-09 14:11:50 UTC        480.0  Hardpoint  Retaliation  Echo Fox
# 4  2017-08-09 14:11:50 UTC        480.0  Hardpoint  Retaliation   Epsilon
#
#     player win? score  ... 4-streak 5-streak 6-streak 7-streak 8+-streak  \
# 0  Methodz    L   106  ...        0        0        0        0         0
# ...

# %%
my_report = sv.compare([champs_2017, "2017"], [champs_2018, "2018"])
my_report.show_html()
# Out:
# /Users/christopherfiore/Documents/GitHub/cwl-data/venv/lib/python3.10/site-packages/sweetviz/dataframe_report.py:74: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_source_names = [cur_name for cur_name, cur_series in source_df.iteritems()]
# /Users/christopherfiore/Documents/GitHub/cwl-data/venv/lib/python3.10/site-packages/sweetviz/dataframe_report.py:92: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   all_compare_names = [cur_name for cur_name, cur_series in compare_df.iteritems()]
# /Users/christopherfiore/Documents/GitHub/cwl-data/venv/lib/python3.10/site-packages/sweetviz/dataframe_report.py:109: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   filtered_series_names_in_source = [cur_name for cur_name, cur_series in source_df.iteritems()
# ...
